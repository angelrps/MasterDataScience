# %% [markdown]
# A practical introduction to Pandas
# ===================

# %% [markdown]
# We have been asked to *analyze an otp dataset*, without much more information. This kind of scenario is more common than you might imagine!
#
# ## 1) Quickly examine the attached file. What does it contain, in both technical and functional terms? (Use any tool you want)

# %%
# !head On_Time_Reporting_Carrier_On_Time_Performance_\(1987_present\)_2019_10.csv
# Out:
# "Year","Quarter","Month","DayofMonth","DayOfWeek","FlightDate","Reporting_Airline","DOT_ID_Reporting_Airline","IATA_CODE_Reporting_Airline","Tail_Number","Flight_Number_Reporting_Airline","OriginAirportID","OriginAirportSeqID","OriginCityMarketID","Origin","OriginCityName","OriginState","OriginStateFips","OriginStateName","OriginWac","DestAirportID","DestAirportSeqID","DestCityMarketID","Dest","DestCityName","DestState","DestStateFips","DestStateName","DestWac","CRSDepTime","DepTime","DepDelay","DepDelayMinutes","DepDel15","DepartureDelayGroups","DepTimeBlk","TaxiOut","WheelsOff","WheelsOn","TaxiIn","CRSArrTime","ArrTime","ArrDelay","ArrDelayMinutes","ArrDel15","ArrivalDelayGroups","ArrTimeBlk","Cancelled","CancellationCode","Diverted","CRSElapsedTime","ActualElapsedTime","AirTime","Flights","Distance","DistanceGroup","CarrierDelay","WeatherDelay","NASDelay","SecurityDelay","LateAircraftDelay","FirstDepTime","TotalAddGTime","LongestAddGTime","DivAirportLandings","DivReachedDest","DivActualElapsedTime","DivArrDelay","DivDistance","Div1Airport","Div1AirportID","Div1AirportSeqID","Div1WheelsOn","Div1TotalGTime","Div1LongestGTime","Div1WheelsOff","Div1TailNum","Div2Airport","Div2AirportID","Div2AirportSeqID","Div2WheelsOn","Div2TotalGTime","Div2LongestGTime","Div2WheelsOff","Div2TailNum","Div3Airport","Div3AirportID","Div3AirportSeqID","Div3WheelsOn","Div3TotalGTime","Div3LongestGTime","Div3WheelsOff","Div3TailNum","Div4Airport","Div4AirportID","Div4AirportSeqID","Div4WheelsOn","Div4TotalGTime","Div4LongestGTime","Div4WheelsOff","Div4TailNum","Div5Airport","Div5AirportID","Div5AirportSeqID","Div5WheelsOn","Div5TotalGTime","Div5LongestGTime","Div5WheelsOff","Div5TailNum",
# 2019,4,10,1,2,2019-10-01,"EV",20366,"EV","N14905","3965",10469,1046902,30469,"AZO","Kalamazoo, MI","MI","26","Michigan",43,13930,1393007,30977,"ORD","Chicago, IL","IL","17","Illinois",41,"0630","0622",-8.00,0.00,0.00,-1,"0600-0659",10.00,"0632","0602",10.00,"0638","0612",-26.00,0.00,0.00,-2,"0600-0659",0.00,"",0.00,68.00,50.00,30.00,1.00,122.00,1,,,,,,"",,,0,,,,,"",,,"",,,"","","",,,"",,,"","","",,,"",,,"","","",,,"",,,"","","",,,"",,,"","",
# 2019,4,10,2,3,2019-10-02,"EV",20366,"EV","N13118","3965",10469,1046902,30469,"AZO","Kalamazoo, MI","MI","26","Michigan",43,13930,1393007,30977,"ORD","Chicago, IL","IL","17","Illinois",41,"0630","0626",-4.00,0.00,0.00,-1,"0600-0659",17.00,"0643","0621",19.00,"0638","0640",2.00,2.00,0.00,0,"0600-0659",0.00,"",0.00,68.00,74.00,38.00,1.00,122.00,1,,,,,,"",,,0,,,,,"",,,"",,,"","","",,,"",,,"","","",,,"",,,"","","",,,"",,,"","","",,,"",,,"","",
# 2019,4,10,3,4,2019-10-03,"EV",20366,"EV","N17185","3965",10469,1046902,30469,"AZO","Kalamazoo, MI","MI","26","Michigan",43,13930,1393007,30977,"ORD","Chicago, IL","IL","17","Illinois",41,"0630","0620",-10.00,0.00,0.00,-1,"0600-0659",21.00,"0641","0612",11.00,"0638","0623",-15.00,0.00,0.00,-1,"0600-0659",0.00,"",0.00,68.00,63.00,31.00,1.00,122.00,1,,,,,,"",,,0,,,,,"",,,"",,,"","","",,,"",,,"","","",,,"",,,"","","",,,"",,,"","","",,,"",,,"","",
# 2019,4,10,4,5,2019-10-04,"EV",20366,"EV","N11107","3965",10469,1046902,30469,"AZO","Kalamazoo, MI","MI","26","Michigan",43,13930,1393007,30977,"ORD","Chicago, IL","IL","17","Illinois",41,"0630","0622",-8.00,0.00,0.00,-1,"0600-0659",13.00,"0635","0607",11.00,"0638","0618",-20.00,0.00,0.00,-2,"0600-0659",0.00,"",0.00,68.00,56.00,32.00,1.00,122.00,1,,,,,,"",,,0,,,,,"",,,"",,,"","","",,,"",,,"","","",,,"",,,"","","",,,"",,,"","","",,,"",,,"","",
# 2019,4,10,5,6,2019-10-05,"EV",20366,"EV","N609UX","3965",11042,1104205,30647,"CLE","Cleveland, OH","OH","39","Ohio",44,12266,1226603,31453,"IAH","Houston, TX","TX","48","Texas",74,"0645","0642",-3.00,0.00,0.00,-1,"0600-0659",22.00,"0704","0829",7.00,"0855","0836",-19.00,0.00,0.00,-2,"0800-0859",0.00,"",0.00,190.00,174.00,145.00,1.00,1091.00,5,,,,,,"",,,0,,,,,"",,,"",,,"","","",,,"",,,"","","",,,"",,,"","","",,,"",,,"","","",,,"",,,"","",
# 2019,4,10,6,7,2019-10-06,"EV",20366,"EV","N603UX","3965",11042,1104205,30647,"CLE","Cleveland, OH","OH","39","Ohio",44,12266,1226603,31453,"IAH","Houston, TX","TX","48","Texas",74,"0645","0638",-7.00,0.00,0.00,-1,"0600-0659",12.00,"0650","0831",14.00,"0855","0845",-10.00,0.00,0.00,-1,"0800-0859",0.00,"",0.00,190.00,187.00,161.00,1.00,1091.00,5,,,,,,"",,,0,,,,,"",,,"",,,"","","",,,"",,,"","","",,,"",,,"","","",,,"",,,"","","",,,"",,,"","",
# 2019,4,10,7,1,2019-10-07,"EV",20366,"EV","N608UX","3965",11042,1104205,30647,"CLE","Cleveland, OH","OH","39","Ohio",44,12266,1226603,31453,"IAH","Houston, TX","TX","48","Texas",74,"0645","0640",-5.00,0.00,0.00,-1,"0600-0659",22.00,"0702","0910",12.00,"0855","0922",27.00,27.00,1.00,1,"0800-0859",0.00,"",0.00,190.00,222.00,188.00,1.00,1091.00,5,0.00,0.00,27.00,0.00,0.00,"",,,0,,,,,"",,,"",,,"","","",,,"",,,"","","",,,"",,,"","","",,,"",,,"","","",,,"",,,"","",
# 2019,4,10,8,2,2019-10-08,"EV",20366,"EV","N606UX","3965",11042,1104205,30647,"CLE","Cleveland, OH","OH","39","Ohio",44,12266,1226603,31453,"IAH","Houston, TX","TX","48","Texas",74,"0645","0643",-2.00,0.00,0.00,-1,"0600-0659",14.00,"0657","0831",7.00,"0855","0838",-17.00,0.00,0.00,-2,"0800-0859",0.00,"",0.00,190.00,175.00,154.00,1.00,1091.00,5,,,,,,"",,,0,,,,,"",,,"",,,"","","",,,"",,,"","","",,,"",,,"","","",,,"",,,"","","",,,"",,,"","",
# 2019,4,10,9,3,2019-10-09,"EV",20366,"EV","N602UX","3965",11042,1104205,30647,"CLE","Cleveland, OH","OH","39","Ohio",44,12266,1226603,31453,"IAH","Houston, TX","TX","48","Texas",74,"0645","0645",0.00,0.00,0.00,0,"0600-0659",15.00,"0700","0840",5.00,"0855","0845",-10.00,0.00,0.00,-1,"0800-0859",0.00,"",0.00,190.00,180.00,160.00,1.00,1091.00,5,,,,,,"",,,0,,,,,"",,,"",,,"","","",,,"",,,"","","",,,"",,,"","","",,,"",,,"","","",,,"",,,"","",

# %% [markdown]
# In this example, I am using the shell from within this notebook, with the ! notation:
#
# A ! sign before a line tells the notebook to send that line straight away to the underlying OS.
#
# \* Note that the specific commands available under the ! sign are dependent on the OS.

# %% [markdown]
# ### Check what the file contains

# %%
! unzip -l On_Time_Reporting_Carrier_On_Time_Performance_1987_present_2019_10.zip
# Out:
# Archive:  On_Time_Reporting_Carrier_On_Time_Performance_1987_present_2019_10.zip
#   Length      Date    Time    Name
# ---------  ---------- -----   ----
# 287692620  2019-12-16 15:42   On_Time_Reporting_Carrier_On_Time_Performance_(1987_present)_2019_10.csv
#     12152  2019-12-16 15:42   readme.html
# ---------                     -------
# 287704772                     2 files

# %% [markdown]
# Oh, it has a readme! Always good to read it.

# %% [markdown]
# ### Unzip the readme to the current directory
#
# Use the shell of your OS or the GUI.
#
# Remember, since zip files contain several compressed files, we need to specify which one we want.

# %% [markdown]
# ### Take a look at the beginning of the readme file
#
# using the shell

# %%
# !head readme.html
# Out:
# <HTML>
# <HEAD>
# 	<TITLE> readme.html </TITLE>
# </HEAD>
# <BODY>
# 	<TABLE><TR><TD COLSPAN=2><H4>BACKGROUND</H4></TD></TR>
# 	<TR><TD COLSPAN=2>The data contained in the compressed file has been extracted from the
# 	Reporting Carrier On-Time Performance (1987-present) data table of the "On-Time" database from the TranStats data library.
# 	The time period is indicated in the name of the compressed file;
# 	for example, XXX_XXXXX_2001_1 contains data of the first month of the year 2001. </TD></TR>

# %% [markdown]
# The readme file is html. Luckily, we are working in an html environment.
#
# ### Display the contents of `readme.html` within the notebook
# (Hint: check out [IPython.display.IFrame](https://ipython.org/ipython-doc/3/api/generated/IPython.display.html))

# %%
from IPython.display import IFrame

IFrame('https://elpais.com', 800, 300)
# Out:
#         <iframe
#             width="800"
#             height="300"
#             src="https://elpais.com"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
IFrame('readme.html', 800, 600)
# Out:
#         <iframe
#             width="800"
#             height="600"
#             src="readme.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# That's some very good documentation!
#
# ### Summary:
#
# The files within the zip are " quoted csv's. They contain information on timeliness of departures in the US, at the departure level.

# %% [markdown]
# ### Load some of the data (one of the files) into memory as a pandas dataframe. What functions do you need to use?
#
# Pro tip: there is no need to decompress the whole file. Check out [zipfile.ZipFile](https://docs.python.org/3/library/zipfile.html)

# %% [markdown]
# First, open a connection to one of the files

# %% [markdown]
# zip_file is a connection to the compressed file, the .zip. We can use it to open a connection to one of the files it contains, which will behave like a normal uncompressed file that we had opened with open()

# %% [markdown]
# Now we're ready to load the file into memory as a pandas dataframe. Remember to close the connections to the files!

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

df = pd.read_csv('On_Time_Reporting_Carrier_On_Time_Performance_(1987_present)_2019_10.csv')
# Out:
# /home/angelrps/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3058: DtypeWarning: Columns (48,77,84) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %% [markdown]
# Let's start examining the data: show the beginning of the file. How many records does it contain?

# %%
df.head()
# Out:
#    Year  Quarter  Month  DayofMonth  DayOfWeek  FlightDate Reporting_Airline  \
# 0  2019        4     10           1          2  2019-10-01                EV
# 1  2019        4     10           2          3  2019-10-02                EV
# 2  2019        4     10           3          4  2019-10-03                EV
# 3  2019        4     10           4          5  2019-10-04                EV
# 4  2019        4     10           5          6  2019-10-05                EV
#
#    DOT_ID_Reporting_Airline IATA_CODE_Reporting_Airline Tail_Number  ...  \
# 0                     20366                          EV      N14905  ...
# 1                     20366                          EV      N13118  ...
# 2                     20366                          EV      N17185  ...
# 3                     20366                          EV      N11107  ...
# 4                     20366                          EV      N609UX  ...
#
#    Div4TailNum  Div5Airport  Div5AirportID  Div5AirportSeqID Div5WheelsOn  \
# 0          NaN          NaN            NaN               NaN          NaN
# 1          NaN          NaN            NaN               NaN          NaN
# 2          NaN          NaN            NaN               NaN          NaN
# 3          NaN          NaN            NaN               NaN          NaN
# 4          NaN          NaN            NaN               NaN          NaN
#
#   Div5TotalGTime Div5LongestGTime  Div5WheelsOff Div5TailNum  Unnamed: 109
# 0            NaN              NaN            NaN         NaN           NaN
# 1            NaN              NaN            NaN         NaN           NaN
# 2            NaN              NaN            NaN         NaN           NaN
# 3            NaN              NaN            NaN         NaN           NaN
# 4            NaN              NaN            NaN         NaN           NaN
#
# [5 rows x 110 columns]

# %%
df.shape
# Out:
# (636014, 110)

# %%
pd.options.display.max_columns = None
df.head()
# Out:
#    Year  Quarter  Month  DayofMonth  DayOfWeek  FlightDate Reporting_Airline  \
# 0  2019        4     10           1          2  2019-10-01                EV
# 1  2019        4     10           2          3  2019-10-02                EV
# 2  2019        4     10           3          4  2019-10-03                EV
# 3  2019        4     10           4          5  2019-10-04                EV
# 4  2019        4     10           5          6  2019-10-05                EV
#
#    DOT_ID_Reporting_Airline IATA_CODE_Reporting_Airline Tail_Number  \
# 0                     20366                          EV      N14905
# 1                     20366                          EV      N13118
# 2                     20366                          EV      N17185
# 3                     20366                          EV      N11107
# 4                     20366                          EV      N609UX
#
#    Flight_Number_Reporting_Airline  OriginAirportID  OriginAirportSeqID  \
# 0                             3965            10469             1046902
# 1                             3965            10469             1046902
# 2                             3965            10469             1046902
# 3                             3965            10469             1046902
# 4                             3965            11042             1104205
#
#    OriginCityMarketID Origin OriginCityName OriginState  OriginStateFips  \
# 0               30469    AZO  Kalamazoo, MI          MI               26
# 1               30469    AZO  Kalamazoo, MI          MI               26
# 2               30469    AZO  Kalamazoo, MI          MI               26
# 3               30469    AZO  Kalamazoo, MI          MI               26
# 4               30647    CLE  Cleveland, OH          OH               39
#
#   OriginStateName  OriginWac  DestAirportID  DestAirportSeqID  \
# 0        Michigan         43          13930           1393007
# 1        Michigan         43          13930           1393007
# 2        Michigan         43          13930           1393007
# 3        Michigan         43          13930           1393007
# 4            Ohio         44          12266           1226603
#
#    DestCityMarketID Dest DestCityName DestState  DestStateFips DestStateName  \
# 0             30977  ORD  Chicago, IL        IL             17      Illinois
# 1             30977  ORD  Chicago, IL        IL             17      Illinois
# 2             30977  ORD  Chicago, IL        IL             17      Illinois
# 3             30977  ORD  Chicago, IL        IL             17      Illinois
# 4             31453  IAH  Houston, TX        TX             48         Texas
#
#    DestWac  CRSDepTime  DepTime  DepDelay  DepDelayMinutes  DepDel15  \
# 0       41         630    622.0      -8.0              0.0       0.0
# 1       41         630    626.0      -4.0              0.0       0.0
# 2       41         630    620.0     -10.0              0.0       0.0
# 3       41         630    622.0      -8.0              0.0       0.0
# 4       74         645    642.0      -3.0              0.0       0.0
#
#    DepartureDelayGroups DepTimeBlk  TaxiOut  WheelsOff  WheelsOn  TaxiIn  \
# 0                  -1.0  0600-0659     10.0      632.0     602.0    10.0
# 1                  -1.0  0600-0659     17.0      643.0     621.0    19.0
# 2                  -1.0  0600-0659     21.0      641.0     612.0    11.0
# 3                  -1.0  0600-0659     13.0      635.0     607.0    11.0
# 4                  -1.0  0600-0659     22.0      704.0     829.0     7.0
#
#    CRSArrTime  ArrTime  ArrDelay  ArrDelayMinutes  ArrDel15  \
# 0         638    612.0     -26.0              0.0       0.0
# 1         638    640.0       2.0              2.0       0.0
# 2         638    623.0     -15.0              0.0       0.0
# 3         638    618.0     -20.0              0.0       0.0
# 4         855    836.0     -19.0              0.0       0.0
#
#    ArrivalDelayGroups ArrTimeBlk  Cancelled CancellationCode  Diverted  \
# 0                -2.0  0600-0659        0.0              NaN       0.0
# 1                 0.0  0600-0659        0.0              NaN       0.0
# 2                -1.0  0600-0659        0.0              NaN       0.0
# 3                -2.0  0600-0659        0.0              NaN       0.0
# 4                -2.0  0800-0859        0.0              NaN       0.0
#
#    CRSElapsedTime  ActualElapsedTime  AirTime  Flights  Distance  \
# 0            68.0               50.0     30.0      1.0     122.0
# 1            68.0               74.0     38.0      1.0     122.0
# 2            68.0               63.0     31.0      1.0     122.0
# 3            68.0               56.0     32.0      1.0     122.0
# 4           190.0              174.0    145.0      1.0    1091.0
#
#    DistanceGroup  CarrierDelay  WeatherDelay  NASDelay  SecurityDelay  \
# 0              1           NaN           NaN       NaN            NaN
# 1              1           NaN           NaN       NaN            NaN
# 2              1           NaN           NaN       NaN            NaN
# 3              1           NaN           NaN       NaN            NaN
# 4              5           NaN           NaN       NaN            NaN
#
#    LateAircraftDelay  FirstDepTime  TotalAddGTime  LongestAddGTime  \
# 0                NaN           NaN            NaN              NaN
# 1                NaN           NaN            NaN              NaN
# 2                NaN           NaN            NaN              NaN
# 3                NaN           NaN            NaN              NaN
# 4                NaN           NaN            NaN              NaN
#
#    DivAirportLandings  DivReachedDest  DivActualElapsedTime  DivArrDelay  \
# 0                   0             NaN                   NaN          NaN
# 1                   0             NaN                   NaN          NaN
# 2                   0             NaN                   NaN          NaN
# 3                   0             NaN                   NaN          NaN
# 4                   0             NaN                   NaN          NaN
#
#    DivDistance Div1Airport  Div1AirportID  Div1AirportSeqID  Div1WheelsOn  \
# 0          NaN         NaN            NaN               NaN           NaN
# 1          NaN         NaN            NaN               NaN           NaN
# 2          NaN         NaN            NaN               NaN           NaN
# 3          NaN         NaN            NaN               NaN           NaN
# 4          NaN         NaN            NaN               NaN           NaN
#
#    Div1TotalGTime  Div1LongestGTime  Div1WheelsOff Div1TailNum Div2Airport  \
# 0             NaN               NaN            NaN         NaN         NaN
# 1             NaN               NaN            NaN         NaN         NaN
# 2             NaN               NaN            NaN         NaN         NaN
# 3             NaN               NaN            NaN         NaN         NaN
# 4             NaN               NaN            NaN         NaN         NaN
#
#    Div2AirportID  Div2AirportSeqID  Div2WheelsOn  Div2TotalGTime  \
# 0            NaN               NaN           NaN             NaN
# 1            NaN               NaN           NaN             NaN
# 2            NaN               NaN           NaN             NaN
# 3            NaN               NaN           NaN             NaN
# 4            NaN               NaN           NaN             NaN
#
#    Div2LongestGTime  Div2WheelsOff Div2TailNum  Div3Airport  Div3AirportID  \
# 0               NaN            NaN         NaN          NaN            NaN
# 1               NaN            NaN         NaN          NaN            NaN
# 2               NaN            NaN         NaN          NaN            NaN
# 3               NaN            NaN         NaN          NaN            NaN
# 4               NaN            NaN         NaN          NaN            NaN
#
#    Div3AirportSeqID  Div3WheelsOn  Div3TotalGTime  Div3LongestGTime  \
# 0               NaN           NaN             NaN               NaN
# 1               NaN           NaN             NaN               NaN
# 2               NaN           NaN             NaN               NaN
# 3               NaN           NaN             NaN               NaN
# 4               NaN           NaN             NaN               NaN
#
#    Div3WheelsOff  Div3TailNum  Div4Airport  Div4AirportID  Div4AirportSeqID  \
# 0            NaN          NaN          NaN            NaN               NaN
# 1            NaN          NaN          NaN            NaN               NaN
# 2            NaN          NaN          NaN            NaN               NaN
# 3            NaN          NaN          NaN            NaN               NaN
# 4            NaN          NaN          NaN            NaN               NaN
#
#    Div4WheelsOn  Div4TotalGTime  Div4LongestGTime  Div4WheelsOff  Div4TailNum  \
# 0           NaN             NaN               NaN            NaN          NaN
# 1           NaN             NaN               NaN            NaN          NaN
# 2           NaN             NaN               NaN            NaN          NaN
# 3           NaN             NaN               NaN            NaN          NaN
# 4           NaN             NaN               NaN            NaN          NaN
#
#    Div5Airport  Div5AirportID  Div5AirportSeqID  Div5WheelsOn  Div5TotalGTime  \
# 0          NaN            NaN               NaN           NaN             NaN
# 1          NaN            NaN               NaN           NaN             NaN
# 2          NaN            NaN               NaN           NaN             NaN
# 3          NaN            NaN               NaN           NaN             NaN
# 4          NaN            NaN               NaN           NaN             NaN
#
#    Div5LongestGTime  Div5WheelsOff  Div5TailNum  Unnamed: 109
# 0               NaN            NaN          NaN           NaN
# 1               NaN            NaN          NaN           NaN
# 2               NaN            NaN          NaN           NaN
# 3               NaN            NaN          NaN           NaN
# 4               NaN            NaN          NaN           NaN

# %% [markdown]
# ## Trimming the data
#
# The table is quite wide, and it seems that there are many columns without much data. Which, exactly, are those? (let's consider empty a column that doesn't contain at least 1000 records, arbitrarily)

# %%
# !head -n 1 On_Time_Reporting_Carrier_On_Time_Performance_\(1987_present\)_2019_10.csv
# Out:
# "Year","Quarter","Month","DayofMonth","DayOfWeek","FlightDate","Reporting_Airline","DOT_ID_Reporting_Airline","IATA_CODE_Reporting_Airline","Tail_Number","Flight_Number_Reporting_Airline","OriginAirportID","OriginAirportSeqID","OriginCityMarketID","Origin","OriginCityName","OriginState","OriginStateFips","OriginStateName","OriginWac","DestAirportID","DestAirportSeqID","DestCityMarketID","Dest","DestCityName","DestState","DestStateFips","DestStateName","DestWac","CRSDepTime","DepTime","DepDelay","DepDelayMinutes","DepDel15","DepartureDelayGroups","DepTimeBlk","TaxiOut","WheelsOff","WheelsOn","TaxiIn","CRSArrTime","ArrTime","ArrDelay","ArrDelayMinutes","ArrDel15","ArrivalDelayGroups","ArrTimeBlk","Cancelled","CancellationCode","Diverted","CRSElapsedTime","ActualElapsedTime","AirTime","Flights","Distance","DistanceGroup","CarrierDelay","WeatherDelay","NASDelay","SecurityDelay","LateAircraftDelay","FirstDepTime","TotalAddGTime","LongestAddGTime","DivAirportLandings","DivReachedDest","DivActualElapsedTime","DivArrDelay","DivDistance","Div1Airport","Div1AirportID","Div1AirportSeqID","Div1WheelsOn","Div1TotalGTime","Div1LongestGTime","Div1WheelsOff","Div1TailNum","Div2Airport","Div2AirportID","Div2AirportSeqID","Div2WheelsOn","Div2TotalGTime","Div2LongestGTime","Div2WheelsOff","Div2TailNum","Div3Airport","Div3AirportID","Div3AirportSeqID","Div3WheelsOn","Div3TotalGTime","Div3LongestGTime","Div3WheelsOff","Div3TailNum","Div4Airport","Div4AirportID","Div4AirportSeqID","Div4WheelsOn","Div4TotalGTime","Div4LongestGTime","Div4WheelsOff","Div4TailNum","Div5Airport","Div5AirportID","Div5AirportSeqID","Div5WheelsOn","Div5TotalGTime","Div5LongestGTime","Div5WheelsOff","Div5TailNum",

# %%
empty_cols = df.columns[df.count() < 1000]
empty_cols
# Out:
# Index(['Div2Airport', 'Div2AirportID', 'Div2AirportSeqID', 'Div2WheelsOn',
#        'Div2TotalGTime', 'Div2LongestGTime', 'Div2WheelsOff', 'Div2TailNum',
#        'Div3Airport', 'Div3AirportID', 'Div3AirportSeqID', 'Div3WheelsOn',
#        'Div3TotalGTime', 'Div3LongestGTime', 'Div3WheelsOff', 'Div3TailNum',
#        'Div4Airport', 'Div4AirportID', 'Div4AirportSeqID', 'Div4WheelsOn',
#        'Div4TotalGTime', 'Div4LongestGTime', 'Div4WheelsOff', 'Div4TailNum',
#        'Div5Airport', 'Div5AirportID', 'Div5AirportSeqID', 'Div5WheelsOn',
#        'Div5TotalGTime', 'Div5LongestGTime', 'Div5WheelsOff', 'Div5TailNum',
#        'Unnamed: 109'],
#       dtype='object')

# %% [markdown]
# It seems that the "diverted" fields, after the first, are often empty. No big surprise, since not that many flights must be diverted more than once in a month. Let's drop those columns, since we are not that interested in those, at least for now.

# %%
df.drop(empty_cols, axis=1)
# Out:
#         Year  Quarter  Month  DayofMonth  DayOfWeek  FlightDate  \
# 0       2019        4     10           1          2  2019-10-01
# 1       2019        4     10           2          3  2019-10-02
# 2       2019        4     10           3          4  2019-10-03
# 3       2019        4     10           4          5  2019-10-04
# 4       2019        4     10           5          6  2019-10-05
# ...      ...      ...    ...         ...        ...         ...
# 636009  2019        4     10          31          4  2019-10-31
# 636010  2019        4     10           1          2  2019-10-01
# 636011  2019        4     10           2          3  2019-10-02
# 636012  2019        4     10           3          4  2019-10-03
# 636013  2019        4     10           4          5  2019-10-04
#
#        Reporting_Airline  DOT_ID_Reporting_Airline  \
# 0                     EV                     20366
# 1                     EV                     20366
# 2                     EV                     20366
# 3                     EV                     20366
# 4                     EV                     20366
# ...                  ...                       ...
# 636009                AA                     19805
# 636010                AA                     19805
# 636011                AA                     19805
# 636012                AA                     19805
# 636013                AA                     19805
#
#        IATA_CODE_Reporting_Airline Tail_Number  \
# 0                               EV      N14905
# 1                               EV      N13118
# 2                               EV      N17185
# 3                               EV      N11107
# 4                               EV      N609UX
# ...                            ...         ...
# 636009                          AA      N774XF
# 636010                          AA      N767UW
# 636011                          AA      N754UW
# 636012                          AA      N837AW
# 636013                          AA      N837AW
#
#         Flight_Number_Reporting_Airline  OriginAirportID  OriginAirportSeqID  \
# 0                                  3965            10469             1046902
# 1                                  3965            10469             1046902
# 2                                  3965            10469             1046902
# 3                                  3965            10469             1046902
# 4                                  3965            11042             1104205
# ...                                 ...              ...                 ...
# 636009                             2301            11298             1129806
# 636010                             2301            13851             1385103
# 636011                             2301            13851             1385103
# 636012                             2301            13851             1385103
# 636013                             2301            13851             1385103
#
#         OriginCityMarketID Origin         OriginCityName OriginState  \
# 0                    30469    AZO          Kalamazoo, MI          MI
# 1                    30469    AZO          Kalamazoo, MI          MI
# 2                    30469    AZO          Kalamazoo, MI          MI
# 3                    30469    AZO          Kalamazoo, MI          MI
# 4                    30647    CLE          Cleveland, OH          OH
# ...                    ...    ...                    ...         ...
# 636009               30194    DFW  Dallas/Fort Worth, TX          TX
# 636010               33851    OKC      Oklahoma City, OK          OK
# 636011               33851    OKC      Oklahoma City, OK          OK
# 636012               33851    OKC      Oklahoma City, OK          OK
# 636013               33851    OKC      Oklahoma City, OK          OK
#
#         OriginStateFips OriginStateName  OriginWac  DestAirportID  \
# 0                    26        Michigan         43          13930
# 1                    26        Michigan         43          13930
# 2                    26        Michigan         43          13930
# 3                    26        Michigan         43          13930
# 4                    39            Ohio         44          12266
# ...                 ...             ...        ...            ...
# 636009               48           Texas         74          13851
# 636010               40        Oklahoma         73          11298
# 636011               40        Oklahoma         73          11298
# 636012               40        Oklahoma         73          11298
# 636013               40        Oklahoma         73          11298
#
#         DestAirportSeqID  DestCityMarketID Dest           DestCityName  \
# 0                1393007             30977  ORD            Chicago, IL
# 1                1393007             30977  ORD            Chicago, IL
# 2                1393007             30977  ORD            Chicago, IL
# 3                1393007             30977  ORD            Chicago, IL
# 4                1226603             31453  IAH            Houston, TX
# ...                  ...               ...  ...                    ...
# 636009           1385103             33851  OKC      Oklahoma City, OK
# 636010           1129806             30194  DFW  Dallas/Fort Worth, TX
# 636011           1129806             30194  DFW  Dallas/Fort Worth, TX
# 636012           1129806             30194  DFW  Dallas/Fort Worth, TX
# 636013           1129806             30194  DFW  Dallas/Fort Worth, TX
#
#        DestState  DestStateFips DestStateName  DestWac  CRSDepTime  DepTime  \
# 0             IL             17      Illinois       41         630    622.0
# 1             IL             17      Illinois       41         630    626.0
# 2             IL             17      Illinois       41         630    620.0
# 3             IL             17      Illinois       41         630    622.0
# 4             TX             48         Texas       74         645    642.0
# ...          ...            ...           ...      ...         ...      ...
# 636009        OK             40      Oklahoma       73         850    916.0
# 636010        TX             48         Texas       74        1028   1019.0
# 636011        TX             48         Texas       74        1028   1025.0
# 636012        TX             48         Texas       74        1031   1019.0
# 636013        TX             48         Texas       74        1031   1035.0
#
#         DepDelay  DepDelayMinutes  DepDel15  DepartureDelayGroups DepTimeBlk  \
# 0           -8.0              0.0       0.0                  -1.0  0600-0659
# 1           -4.0              0.0       0.0                  -1.0  0600-0659
# 2          -10.0              0.0       0.0                  -1.0  0600-0659
# 3           -8.0              0.0       0.0                  -1.0  0600-0659
# 4           -3.0              0.0       0.0                  -1.0  0600-0659
# ...          ...              ...       ...                   ...        ...
# 636009      26.0             26.0       1.0                   1.0  0800-0859
# 636010      -9.0              0.0       0.0                  -1.0  1000-1059
# 636011      -3.0              0.0       0.0                  -1.0  1000-1059
# 636012     -12.0              0.0       0.0                  -1.0  1000-1059
# 636013       4.0              4.0       0.0                   0.0  1000-1059
#
#         TaxiOut  WheelsOff  WheelsOn  TaxiIn  CRSArrTime  ArrTime  ArrDelay  \
# 0          10.0      632.0     602.0    10.0         638    612.0     -26.0
# 1          17.0      643.0     621.0    19.0         638    640.0       2.0
# 2          21.0      641.0     612.0    11.0         638    623.0     -15.0
# 3          13.0      635.0     607.0    11.0         638    618.0     -20.0
# 4          22.0      704.0     829.0     7.0         855    836.0     -19.0
# ...         ...        ...       ...     ...         ...      ...       ...
# 636009     27.0      943.0    1019.0     3.0         950   1022.0      32.0
# 636010     12.0     1031.0    1104.0    14.0        1140   1118.0     -22.0
# 636011     10.0     1035.0    1112.0    15.0        1140   1127.0     -13.0
# 636012     17.0     1036.0    1115.0    11.0        1148   1126.0     -22.0
# 636013     13.0     1048.0    1122.0    11.0        1148   1133.0     -15.0
#
#         ArrDelayMinutes  ArrDel15  ArrivalDelayGroups ArrTimeBlk  Cancelled  \
# 0                   0.0       0.0                -2.0  0600-0659        0.0
# 1                   2.0       0.0                 0.0  0600-0659        0.0
# 2                   0.0       0.0                -1.0  0600-0659        0.0
# 3                   0.0       0.0                -2.0  0600-0659        0.0
# 4                   0.0       0.0                -2.0  0800-0859        0.0
# ...                 ...       ...                 ...        ...        ...
# 636009             32.0       1.0                 2.0  0900-0959        0.0
# 636010              0.0       0.0                -2.0  1100-1159        0.0
# 636011              0.0       0.0                -1.0  1100-1159        0.0
# 636012              0.0       0.0                -2.0  1100-1159        0.0
# 636013              0.0       0.0                -1.0  1100-1159        0.0
#
#        CancellationCode  Diverted  CRSElapsedTime  ActualElapsedTime  AirTime  \
# 0                   NaN       0.0            68.0               50.0     30.0
# 1                   NaN       0.0            68.0               74.0     38.0
# 2                   NaN       0.0            68.0               63.0     31.0
# 3                   NaN       0.0            68.0               56.0     32.0
# 4                   NaN       0.0           190.0              174.0    145.0
# ...                 ...       ...             ...                ...      ...
# 636009              NaN       0.0            60.0               66.0     36.0
# 636010              NaN       0.0            72.0               59.0     33.0
# 636011              NaN       0.0            72.0               62.0     37.0
# 636012              NaN       0.0            77.0               67.0     39.0
# 636013              NaN       0.0            77.0               58.0     34.0
#
#         Flights  Distance  DistanceGroup  CarrierDelay  WeatherDelay  \
# 0           1.0     122.0              1           NaN           NaN
# 1           1.0     122.0              1           NaN           NaN
# 2           1.0     122.0              1           NaN           NaN
# 3           1.0     122.0              1           NaN           NaN
# 4           1.0    1091.0              5           NaN           NaN
# ...         ...       ...            ...           ...           ...
# 636009      1.0     175.0              1           2.0           0.0
# 636010      1.0     175.0              1           NaN           NaN
# 636011      1.0     175.0              1           NaN           NaN
# 636012      1.0     175.0              1           NaN           NaN
# 636013      1.0     175.0              1           NaN           NaN
#
#         NASDelay  SecurityDelay  LateAircraftDelay  FirstDepTime  \
# 0            NaN            NaN                NaN           NaN
# 1            NaN            NaN                NaN           NaN
# 2            NaN            NaN                NaN           NaN
# 3            NaN            NaN                NaN           NaN
# 4            NaN            NaN                NaN           NaN
# ...          ...            ...                ...           ...
# 636009       6.0            0.0               24.0           NaN
# 636010       NaN            NaN                NaN           NaN
# 636011       NaN            NaN                NaN           NaN
# 636012       NaN            NaN                NaN           NaN
# 636013       NaN            NaN                NaN           NaN
#
#         TotalAddGTime  LongestAddGTime  DivAirportLandings  DivReachedDest  \
# 0                 NaN              NaN                   0             NaN
# 1                 NaN              NaN                   0             NaN
# 2                 NaN              NaN                   0             NaN
# 3                 NaN              NaN                   0             NaN
# 4                 NaN              NaN                   0             NaN
# ...               ...              ...                 ...             ...
# 636009            NaN              NaN                   0             NaN
# 636010            NaN              NaN                   0             NaN
# 636011            NaN              NaN                   0             NaN
# 636012            NaN              NaN                   0             NaN
# 636013            NaN              NaN                   0             NaN
#
#         DivActualElapsedTime  DivArrDelay  DivDistance Div1Airport  \
# 0                        NaN          NaN          NaN         NaN
# 1                        NaN          NaN          NaN         NaN
# 2                        NaN          NaN          NaN         NaN
# 3                        NaN          NaN          NaN         NaN
# 4                        NaN          NaN          NaN         NaN
# ...                      ...          ...          ...         ...
# 636009                   NaN          NaN          NaN         NaN
# 636010                   NaN          NaN          NaN         NaN
# 636011                   NaN          NaN          NaN         NaN
# 636012                   NaN          NaN          NaN         NaN
# 636013                   NaN          NaN          NaN         NaN
#
#         Div1AirportID  Div1AirportSeqID  Div1WheelsOn  Div1TotalGTime  \
# 0                 NaN               NaN           NaN             NaN
# 1                 NaN               NaN           NaN             NaN
# 2                 NaN               NaN           NaN             NaN
# 3                 NaN               NaN           NaN             NaN
# 4                 NaN               NaN           NaN             NaN
# ...               ...               ...           ...             ...
# 636009            NaN               NaN           NaN             NaN
# 636010            NaN               NaN           NaN             NaN
# 636011            NaN               NaN           NaN             NaN
# 636012            NaN               NaN           NaN             NaN
# 636013            NaN               NaN           NaN             NaN
#
#         Div1LongestGTime  Div1WheelsOff Div1TailNum
# 0                    NaN            NaN         NaN
# 1                    NaN            NaN         NaN
# 2                    NaN            NaN         NaN
# 3                    NaN            NaN         NaN
# 4                    NaN            NaN         NaN
# ...                  ...            ...         ...
# 636009               NaN            NaN         NaN
# 636010               NaN            NaN         NaN
# 636011               NaN            NaN         NaN
# 636012               NaN            NaN         NaN
# 636013               NaN            NaN         NaN
#
# [636014 rows x 77 columns]

# %%
df.dropna(axis=1, thresh=1000).shape == df.drop(empty_cols, axis=1).shape
# Out:
# True

# %%
df2 = df.dropna(axis=1, thresh=1000)

# %% [markdown]
# Now that we have eliminated some inconvenient data columns, let's have a look at the rest: let's loook at how the location data is encoded.

# %% [markdown]
# #### Exercise:
#
# First, generate a list of the columns that have 'Origin' in their name
#
# Second, show a sample of the values that those columns take.
#
# Hint: we are going to use the str attribute of Series and Indexes

# %%
df2['Tail_Number'].str[0].value_counts()
# Out:
# N    627754
# 2      4921
# 3      2945
# Name: Tail_Number, dtype: int64

# %%
origin_col_names = df2.columns[df2.columns.str.contains('Origin')]
origin_col_names
# Out:
# Index(['OriginAirportID', 'OriginAirportSeqID', 'OriginCityMarketID', 'Origin',
#        'OriginCityName', 'OriginState', 'OriginStateFips', 'OriginStateName',
#        'OriginWac'],
#       dtype='object')

# %%
df2[origin_col_names].sample(5)
# Out:
#         OriginAirportID  OriginAirportSeqID  OriginCityMarketID Origin  \
# 184770            12889             1288903               32211    LAS
# 484341            11292             1129202               30325    DEN
# 216225            11278             1127805               30852    DCA
# 142431            14679             1467903               33570    SAN
# 477727            12266             1226603               31453    IAH
#
#         OriginCityName OriginState  OriginStateFips OriginStateName  OriginWac
# 184770   Las Vegas, NV          NV               32          Nevada         85
# 484341      Denver, CO          CO                8        Colorado         82
# 216225  Washington, DC          VA               51        Virginia         38
# 142431   San Diego, CA          CA                6      California         91
# 477727     Houston, TX          TX               48           Texas         74

# %%
df2[origin_col_names].sort_values(by='Origin').head(5)
# Out:
#         OriginAirportID  OriginAirportSeqID  OriginCityMarketID Origin  \
# 313277            10135             1013505               30135    ABE
# 310264            10135             1013505               30135    ABE
# 47163             10135             1013505               30135    ABE
# 310263            10135             1013505               30135    ABE
# 310262            10135             1013505               30135    ABE
#
#                         OriginCityName OriginState  OriginStateFips  \
# 313277  Allentown/Bethlehem/Easton, PA          PA               42
# 310264  Allentown/Bethlehem/Easton, PA          PA               42
# 47163   Allentown/Bethlehem/Easton, PA          PA               42
# 310263  Allentown/Bethlehem/Easton, PA          PA               42
# 310262  Allentown/Bethlehem/Easton, PA          PA               42
#
#        OriginStateName  OriginWac
# 313277    Pennsylvania         23
# 310264    Pennsylvania         23
# 47163     Pennsylvania         23
# 310263    Pennsylvania         23
# 310262    Pennsylvania         23

# %%
df2[origin_col_names].sample(5)
# Out:
#         OriginAirportID  OriginAirportSeqID  OriginCityMarketID Origin  \
# 184770            12889             1288903               32211    LAS
# 484341            11292             1129202               30325    DEN
# 216225            11278             1127805               30852    DCA
# 142431            14679             1467903               33570    SAN
# 477727            12266             1226603               31453    IAH
#
#         OriginCityName OriginState  OriginStateFips OriginStateName  OriginWac
# 184770   Las Vegas, NV          NV               32          Nevada         85
# 484341      Denver, CO          CO                8        Colorado         82
# 216225  Washington, DC          VA               51        Virginia         38
# 142431   San Diego, CA          CA                6      California         91
# 477727     Houston, TX          TX               48           Texas         74

# %% [markdown]
# So much redundant information!

# %% [markdown]
# ## Fast forward
#
# Just taking out the redundant columns would take a while, so let's jump ahead with this list of interesting columns:
#
# ```python
# interesting_columns= ['FlightDate', 'DayOfWeek', 'Reporting_Airline', 'Tail_Number', 'Flight_Number_Reporting_Airline',
#                       'Origin', 'OriginCityName', 'OriginStateName', 'OriginCityMarketID',
#                       'Dest', 'DestCityName', 'DestStateName', 'DestCityMarketID',
#                       'DepTime', 'DepDelay', 'AirTime', 'Distance']
# ```

# %%
interesting_columns = ['FlightDate', 'DayOfWeek', 'Reporting_Airline', 'Tail_Number', 'Flight_Number_Reporting_Airline', 
                      'Origin', 'OriginCityName', 'OriginStateName', 'OriginCityMarketID',
                      'Dest', 'DestCityName', 'DestStateName', 'DestCityMarketID',
                      'DepTime', 'DepDelay', 'AirTime', 'Distance']

df3 = df2[interesting_columns]
df3.head()
# Out:
#    FlightDate  DayOfWeek Reporting_Airline Tail_Number  \
# 0  2019-10-01          2                EV      N14905
# 1  2019-10-02          3                EV      N13118
# 2  2019-10-03          4                EV      N17185
# 3  2019-10-04          5                EV      N11107
# 4  2019-10-05          6                EV      N609UX
#
#    Flight_Number_Reporting_Airline Origin OriginCityName OriginStateName  \
# 0                             3965    AZO  Kalamazoo, MI        Michigan
# 1                             3965    AZO  Kalamazoo, MI        Michigan
# 2                             3965    AZO  Kalamazoo, MI        Michigan
# 3                             3965    AZO  Kalamazoo, MI        Michigan
# 4                             3965    CLE  Cleveland, OH            Ohio
#
#    OriginCityMarketID Dest DestCityName DestStateName  DestCityMarketID  \
# 0               30469  ORD  Chicago, IL      Illinois             30977
# 1               30469  ORD  Chicago, IL      Illinois             30977
# 2               30469  ORD  Chicago, IL      Illinois             30977
# 3               30469  ORD  Chicago, IL      Illinois             30977
# 4               30647  IAH  Houston, TX         Texas             31453
#
#    DepTime  DepDelay  AirTime  Distance
# 0    622.0      -8.0     30.0     122.0
# 1    626.0      -4.0     38.0     122.0
# 2    620.0     -10.0     31.0     122.0
# 3    622.0      -8.0     32.0     122.0
# 4    642.0      -3.0    145.0    1091.0

# %% [markdown]
# ## Formatting columns and parsing dates and times
#
# Hurray! we have almost cleaned our dataset. Soon we will begin to do some actual work with it.

# %% [markdown]
# Pandas interpreted the Deptime column as ints and the FlightDate column as strings. We might want to combine them and parse them into a DateTime column, so that we can use them properly as datetimes. For that, we would need to use [pd.to_datetime](http://pandas.pydata.org/pandas-docs/stable/generated/pandas.to_datetime.html).

# %%
df3['DepTime']
# Out:
# 0          622.0
# 1          626.0
# 2          620.0
# 3          622.0
# 4          642.0
#            ...
# 636009     916.0
# 636010    1019.0
# 636011    1025.0
# 636012    1019.0
# 636013    1035.0
# Name: DepTime, Length: 636014, dtype: float64

# %% [markdown]
# Also, a pet peeve of mine: Flight numbers are names, not numbers!

# %%
df3['Flight_Number_Reporting_Airline'].astype(object)
df3['Flight_Number_Reporting_Airline'] = df3['Flight_Number_Reporting_Airline'].astype(object)
df3.dtypes
# Out:
# /home/dani/anaconda3/envs/master2020/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# FlightDate                          object
# DayOfWeek                            int64
# Reporting_Airline                   object
# Tail_Number                         object
# Flight_Number_Reporting_Airline     object
# Origin                              object
# OriginCityName                      object
# OriginStateName                     object
# OriginCityMarketID                   int64
# Dest                                object
# DestCityName                        object
# DestStateName                       object
# DestCityMarketID                     int64
# DepTime                            float64
# DepDelay                           float64
# AirTime                            float64
# Distance                           float64
# dtype: object

# %%
df3['DepTime'].sample(5)
# Out:
# 47577      743.0
# 581031    1241.0
# 274162    1722.0
# 433848    1827.0
# 625983    1734.0
# Name: DepTime, dtype: float64

# %%
df3['Hour'] = (df3['DepTime'] // 100)
# Out:
# /home/dani/anaconda3/envs/master2020/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df3['Hour'] = (df3['DepTime'] // 100).astype(int)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-64-b335c3f6912b> in <module>
# ----> 1 df3['Hour'] = (df3['DepTime'] // 100).astype(int)
#
# ~/anaconda3/envs/master2020/lib/python3.7/site-packages/pandas/core/generic.py in astype(self, dtype, copy, errors, **kwargs)
#    5880             # else, only a single dtype is given
#    5881             new_data = self._data.astype(
# -> 5882                 dtype=dtype, copy=copy, errors=errors, **kwargs
#    5883             )
#    5884             return self._constructor(new_data).__finalize__(self)
#
# ~/anaconda3/envs/master2020/lib/python3.7/site-packages/pandas/core/internals/managers.py in astype(self, dtype, **kwargs)
#     579
#     580     def astype(self, dtype, **kwargs):
# --> 581         return self.apply("astype", dtype=dtype, **kwargs)
#     582
#     583     def convert(self, **kwargs):
#
# ~/anaconda3/envs/master2020/lib/python3.7/site-packages/pandas/core/internals/managers.py in apply(self, f, axes, filter, do_integrity_check, consolidate, **kwargs)
#     436                     kwargs[k] = obj.reindex(b_items, axis=axis, copy=align_copy)
#     437
# --> 438             applied = getattr(b, f)(**kwargs)
#     439             result_blocks = _extend_blocks(applied, result_blocks)
#     440
#
# ~/anaconda3/envs/master2020/lib/python3.7/site-packages/pandas/core/internals/blocks.py in astype(self, dtype, copy, errors, values, **kwargs)
#     557
#     558     def astype(self, dtype, copy=False, errors="raise", values=None, **kwargs):
# --> 559         return self._astype(dtype, copy=copy, errors=errors, values=values, **kwargs)
#     560
#     561     def _astype(self, dtype, copy=False, errors="raise", values=None, **kwargs):
#
# ~/anaconda3/envs/master2020/lib/python3.7/site-packages/pandas/core/internals/blocks.py in _astype(self, dtype, copy, errors, values, **kwargs)
#     641                     # _astype_nansafe works fine with 1-d only
#     642                     vals1d = values.ravel()
# --> 643                     values = astype_nansafe(vals1d, dtype, copy=True, **kwargs)
#     644
#     645                 # TODO(extension)
#
# ~/anaconda3/envs/master2020/lib/python3.7/site-packages/pandas/core/dtypes/cast.py in astype_nansafe(arr, dtype, copy, skipna)
#     698         if not np.isfinite(arr).all():
#     699             raise ValueError(
# --> 700                 "Cannot convert non-finite values (NA or inf) to " "integer"
#     701             )
#     702
#
# ValueError: Cannot convert non-finite values (NA or inf) to integer

# %%
df3['Hour']
# Out:
# 0          6.0
# 1          6.0
# 2          6.0
# 3          6.0
# 4          6.0
#           ...
# 636009     9.0
# 636010    10.0
# 636011    10.0
# 636012    10.0
# 636013    10.0
# Name: Hour, Length: 636014, dtype: float64

# %% [markdown]
# ## Examining the data

# %% [markdown]
# Finally clean! Let's start to do some preliminary work on the data.

# %% [markdown]
# #### Exercise:
#
# Find the biggest delays: 5 maximum delays.

# %%
df3.sort_values(by='DepDelay', ascending=False).head(5)
# Out:
#         FlightDate  DayOfWeek Reporting_Airline Tail_Number  \
# 86809   2019-10-30          3                YV      N955LR
# 570567  2019-10-18          5                AA      N207UW
# 357965  2019-10-22          2                B6      N569JB
# 34370   2019-10-30          3                MQ      N541EA
# 557511  2019-10-24          4                AA      N871NN
#
#        Flight_Number_Reporting_Airline Origin      OriginCityName  \
# 86809                             5860    SDF      Louisville, KY
# 570567                            1552    DCA      Washington, DC
# 357965                             231    SLC  Salt Lake City, UT
# 34370                             3657    GRR    Grand Rapids, MI
# 557511                             189    ABQ     Albuquerque, NM
#
#        OriginStateName  OriginCityMarketID Dest           DestCityName  \
# 86809         Kentucky               33044  DFW  Dallas/Fort Worth, TX
# 570567        Virginia               30852  PHX            Phoenix, AZ
# 357965            Utah               34614  LGB         Long Beach, CA
# 34370         Michigan               31986  ORD            Chicago, IL
# 557511      New Mexico               30140  DFW  Dallas/Fort Worth, TX
#
#        DestStateName  DestCityMarketID  DepTime  DepDelay  AirTime  Distance  \
# 86809          Texas             30194   2031.0    2036.0    109.0     733.0
# 570567       Arizona             30466   1555.0    1964.0    258.0    1979.0
# 357965    California             32575   1608.0    1769.0     79.0     588.0
# 34370       Illinois             30977   1820.0    1687.0     31.0     137.0
# 557511         Texas             30194   1517.0    1602.0     92.0     569.0
#
#         Hour
# 86809   20.0
# 570567  15.0
# 357965  16.0
# 34370   18.0
# 557511  15.0

# %% [markdown]
# #### Exercise
#
# What was the average delay for this month? Standard deviation and typical value?

# %%
# %%time
df3.describe()['DepDelay']
# Out:
# CPU times: user 1.11 s, sys: 35.8 ms, total: 1.15 s
# Wall time: 312 ms
# count    631100.000000
# mean          7.880767
# std          41.946828
# min         -48.000000
# 25%          -6.000000
# 50%          -3.000000
# 75%           4.000000
# max        2036.000000
# Name: DepDelay, dtype: float64

# %%
# %%time
df3['DepDelay'].describe()
# Out:
# CPU times: user 185 ms, sys: 8.23 ms, total: 194 ms
# Wall time: 54 ms
# count    631100.000000
# mean          7.880767
# std          41.946828
# min         -48.000000
# 25%          -6.000000
# 50%          -3.000000
# 75%           4.000000
# max        2036.000000
# Name: DepDelay, dtype: float64

# %% [markdown]
# Also: a quick look at the correlation between the numerical variables is extremely easy with pandas:

# %%
import seaborn as sns

sns.heatmap(df3.corr())

# %% [markdown]
# #### Exercise
#
# What is the plane that has the highest average delay? We'll first group by tail number (the *license plate* of a plane) and then calculate the relevant statistic for each group (group of *departures*)

# %%
# %%time
df3.groupby('Tail_Number')['DepDelay'].mean()
# Out:
# CPU times: user 82.1 ms, sys: 8.1 ms, total: 90.2 ms
# Wall time: 86.4 ms
# Tail_Number
# 215NV      2.834862
# 216NV     13.278481
# 217NV      3.504425
# 218NV      4.463636
# 219NV      5.656934
#             ...
# N998DL     2.886598
# N998JE     5.949153
# N998NN    12.833333
# N999DN     0.691176
# N999JQ    16.847222
# Name: DepDelay, Length: 5416, dtype: float64

# %%
# %%time
df3.groupby('Tail_Number').mean()['DepDelay']
# Out:
# CPU times: user 162 ms, sys: 28.1 ms, total: 190 ms
# Wall time: 186 ms
# Tail_Number
# 215NV      2.834862
# 216NV     13.278481
# 217NV      3.504425
# 218NV      4.463636
# 219NV      5.656934
#             ...
# N998DL     2.886598
# N998JE     5.949153
# N998NN    12.833333
# N999DN     0.691176
# N999JQ    16.847222
# Name: DepDelay, Length: 5416, dtype: float64

# %%
df3[df3['FlightDate']=='2019-10-22'].groupby('Tail_Number')['DepDelay'].mean()
# Out:
# Tail_Number
# 215NV     -1.500000
# 216NV     -8.500000
# 217NV     -4.000000
# 218NV     59.500000
# 219NV     43.000000
#             ...
# N998AT    -0.500000
# N998DL    -0.333333
# N998JE     0.000000
# N998NN    -4.250000
# N999JQ    45.200000
# Name: DepDelay, Length: 4634, dtype: float64

# %%
df3.groupby(['Tail_Number', 'FlightDate'])['DepDelay'].mean()
# Out:
# Tail_Number  FlightDate
# 215NV        2019-10-03    -1.666667
#              2019-10-04    -7.333333
#              2019-10-05    28.500000
#              2019-10-06     0.333333
#              2019-10-07    -3.000000
#                              ...
# N999JQ       2019-10-25    -5.000000
#              2019-10-26   -10.000000
#              2019-10-27    -7.000000
#              2019-10-28    -5.500000
#              2019-10-29     4.500000
# Name: DepDelay, Length: 143882, dtype: float64

# %%
df3[(df3['FlightDate'] < '2019-10-15') and (df3['FlightDate'] > '2019-10-10')]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-90-5da72b1ea501> in <module>
# ----> 1 df3[(df3['FlightDate'] < '2019-10-15') and (df3['FlightDate'] > '2019-10-10')]
#
# ~/anaconda3/envs/master2020/lib/python3.7/site-packages/pandas/core/generic.py in __nonzero__(self)
#    1553             "The truth value of a {0} is ambiguous. "
#    1554             "Use a.empty, a.bool(), a.item(), a.any() or a.all().".format(
# -> 1555                 self.__class__.__name__
#    1556             )
#    1557         )
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
df3[(df3['FlightDate'] < '2019-10-15') & (df3['FlightDate'] > '2019-10-10')]
# Out:
#         FlightDate  DayOfWeek Reporting_Airline Tail_Number  \
# 10      2019-10-11          5                EV      N602UX
# 11      2019-10-12          6                EV      N603UX
# 12      2019-10-13          7                EV      N604UX
# 13      2019-10-14          1                EV      N610UX
# 43      2019-10-13          7                EV      N17115
# ...            ...        ...               ...         ...
# 635962  2019-10-14          1                AA      N980NN
# 635989  2019-10-11          5                AA      N825AW
# 635990  2019-10-12          6                AA      N767UW
# 635991  2019-10-13          7                AA      N765US
# 635992  2019-10-14          1                AA      N770UW
#
#        Flight_Number_Reporting_Airline Origin         OriginCityName  \
# 10                                3965    CLE          Cleveland, OH
# 11                                3965    CLE          Cleveland, OH
# 12                                3965    CLE          Cleveland, OH
# 13                                3965    CLE          Cleveland, OH
# 43                                3966    ORD            Chicago, IL
# ...                                ...    ...                    ...
# 635962                            2300    ORD            Chicago, IL
# 635989                            2301    DFW  Dallas/Fort Worth, TX
# 635990                            2301    DFW  Dallas/Fort Worth, TX
# 635991                            2301    DFW  Dallas/Fort Worth, TX
# 635992                            2301    DFW  Dallas/Fort Worth, TX
#
#        OriginStateName  OriginCityMarketID Dest           DestCityName  \
# 10                Ohio               30647  IAH            Houston, TX
# 11                Ohio               30647  IAH            Houston, TX
# 12                Ohio               30647  IAH            Houston, TX
# 13                Ohio               30647  IAH            Houston, TX
# 43            Illinois               30977  ICT            Wichita, KS
# ...                ...                 ...  ...                    ...
# 635962        Illinois               30977  DFW  Dallas/Fort Worth, TX
# 635989           Texas               30194  OKC      Oklahoma City, OK
# 635990           Texas               30194  OKC      Oklahoma City, OK
# 635991           Texas               30194  OKC      Oklahoma City, OK
# 635992           Texas               30194  OKC      Oklahoma City, OK
#
#        DestStateName  DestCityMarketID  DepTime  DepDelay  AirTime  Distance  \
# 10             Texas             31453    644.0      -1.0    161.0    1091.0
# 11             Texas             31453    638.0      -7.0    169.0    1091.0
# 12             Texas             31453    640.0      -5.0    177.0    1091.0
# 13             Texas             31453    641.0      -4.0    165.0    1091.0
# 43            Kansas             30928   1531.0      -4.0     89.0     588.0
# ...              ...               ...      ...       ...      ...       ...
# 635962         Texas             30194   1821.0       6.0    117.0     801.0
# 635989      Oklahoma             33851    900.0      10.0     29.0     175.0
# 635990      Oklahoma             33851    846.0      -4.0     40.0     175.0
# 635991      Oklahoma             33851    847.0      -3.0     37.0     175.0
# 635992      Oklahoma             33851    849.0      -1.0     38.0     175.0
#
#         Hour
# 10       6.0
# 11       6.0
# 12       6.0
# 13       6.0
# 43      15.0
# ...      ...
# 635962  18.0
# 635989   9.0
# 635990   8.0
# 635991   8.0
# 635992   8.0
#
# [81709 rows x 18 columns]

# %%
df3.groupby('Tail_Number')['DepDelay'].mean().sort_values(ascending=False).head(10)
# Out:
# Tail_Number
# N26970    279.00
# N820AL    211.30
# N724AN    202.00
# N284JB    148.00
# N271AY    137.00
# N35953    122.00
# N9012     116.75
# N224UA    115.50
# N77014    113.00
# N1611B    113.00
# Name: DepDelay, dtype: float64

# %% [markdown]
# Oh, but those numbers smell like these planes had only a few, very delayed, departures! how can we count the number of departures *and* calculate the average delay at the same time?

# %%
df3.groupby('Tail_Number')['DepDelay'].agg(['mean', 'count']).sort_values(by='mean', ascending=False).head()
# Out:
#               mean  count
# Tail_Number
# N26970       279.0      1
# N820AL       211.3     10
# N724AN       202.0      2
# N284JB       148.0      3
# N271AY       137.0      2

# %%
df3[df3['Tail_Number']=='N820AL']
# Out:
#         FlightDate  DayOfWeek Reporting_Airline Tail_Number  \
# 555132  2019-10-31          4                AA      N820AL
# 555221  2019-10-31          4                AA      N820AL
# 556214  2019-10-17          4                AA      N820AL
# 556224  2019-10-27          7                AA      N820AL
# 556227  2019-10-30          3                AA      N820AL
# 574241  2019-10-16          3                AA      N820AL
# 574254  2019-10-29          2                AA      N820AL
# 575450  2019-10-07          1                AA      N820AL
# 578284  2019-10-11          5                AA      N820AL
# 585924  2019-10-22          2                AA      N820AL
#
#        Flight_Number_Reporting_Airline Origin         OriginCityName  \
# 555132                               5    DFW  Dallas/Fort Worth, TX
# 555221                               8    HNL           Honolulu, HI
# 556214                             116    ORD            Chicago, IL
# 556224                             116    ORD            Chicago, IL
# 556227                             116    ORD            Chicago, IL
# 574241                            2412    DFW  Dallas/Fort Worth, TX
# 574254                            2412    DFW  Dallas/Fort Worth, TX
# 575450                            2453    DFW  Dallas/Fort Worth, TX
# 578284                            2543    LAX        Los Angeles, CA
# 585924                            1258    DFW  Dallas/Fort Worth, TX
#
#        OriginStateName  OriginCityMarketID Dest           DestCityName  \
# 555132           Texas               30194  HNL           Honolulu, HI
# 555221          Hawaii               32134  DFW  Dallas/Fort Worth, TX
# 556214        Illinois               30977  DFW  Dallas/Fort Worth, TX
# 556224        Illinois               30977  DFW  Dallas/Fort Worth, TX
# 556227        Illinois               30977  DFW  Dallas/Fort Worth, TX
# 574241           Texas               30194  ORD            Chicago, IL
# 574254           Texas               30194  ORD            Chicago, IL
# 575450           Texas               30194  LAX        Los Angeles, CA
# 578284      California               32575  DFW  Dallas/Fort Worth, TX
# 585924           Texas               30194  ORD            Chicago, IL
#
#        DestStateName  DestCityMarketID  DepTime  DepDelay  AirTime  Distance  \
# 555132        Hawaii             32134   1119.0      -1.0    457.0    3784.0
# 555221         Texas             30194   1906.0    1546.0    393.0    3784.0
# 556214         Texas             30194    357.0     442.0     99.0     801.0
# 556224         Texas             30194   2157.0      82.0    112.0     801.0
# 556227         Texas             30194   2043.0       8.0    129.0     801.0
# 574241      Illinois             30977   1227.0      -3.0    111.0     801.0
# 574254      Illinois             30977   1225.0      -5.0    104.0     801.0
# 575450    California             32575   1847.0      -3.0    168.0    1235.0
# 578284         Texas             30194   1348.0       3.0    138.0    1235.0
# 585924      Illinois             30977   1234.0      44.0    105.0     801.0
#
#         Hour
# 555132  11.0
# 555221  19.0
# 556214   3.0
# 556224  21.0
# 556227  20.0
# 574241  12.0
# 574254  12.0
# 575450  18.0
# 578284  13.0
# 585924  12.0

# %% [markdown]
# Awesome! now, let's look at the average delay of the planes with some departures (let's say, at least 15)

# %%
delays = df3.groupby('Tail_Number')['DepDelay'].agg(['mean', 'count'])
consistently_late = delays[delays['count'] >= 15].sort_values(by='mean', ascending=False)

consistently_late
# Out:
#                    mean  count
# Tail_Number
# N350AN       102.941176     17
# N15986        70.444444     27
# N12003        66.391304     23
# 242NV         64.426829     82
# N116DU        61.974359    117
# ...                 ...    ...
# N631VA        -5.904762     21
# N611AS        -6.261307    199
# N240JQ        -6.666667     18
# N613AS        -6.813953    172
# N36280       -14.600000     20
#
# [5069 rows x 2 columns]

# %% [markdown]
# #### Exercise:
#
# Show cities by descending number of airports

# %%
df3.groupby('OriginCityName')['Origin']\
   .agg(['nunique', 'unique'])\
   .sort_values(by='nunique', ascending=False)\
   .head(10)
# Out:
#                          nunique      unique
# OriginCityName
# Houston, TX                    2  [IAH, HOU]
# New York, NY                   2  [LGA, JFK]
# Chicago, IL                    2  [ORD, MDW]
# Williston, ND                  2  [ISN, XWA]
# Phoenix, AZ                    2  [PHX, AZA]
# Columbus, OH                   2  [CMH, LCK]
# Mobile, AL                     2  [MOB, BFM]
# Washington, DC                 2  [DCA, IAD]
# North Bend/Coos Bay, OR        1       [OTH]
# Omaha, NE                      1       [OMA]

# %% [markdown]
# #### Exercise
#
# The list above doesn't correspond to our intuitive expectation, probably. That is because airports serving the same general area may be located within several different city limits. This is encapsulated by the "market" concept in commercial aviation.
#
# Find the 10 markets with the most airports, and which airports are included in them.

# %%
df3.groupby('OriginCityMarketID')[['Origin', 'OriginCityName']]\
   .agg(['nunique', 'unique'])\
   .sort_values(by=('Origin','nunique'), ascending=False)\
   .head(10)
# Out:
#                     Origin                                 OriginCityName  \
#                    nunique                          unique        nunique
# OriginCityMarketID
# 31703                    6  [EWR, LGA, JFK, SWF, HPN, ISP]              5
# 32575                    5       [LAX, LGB, BUR, ONT, SNA]              5
# 30852                    3                 [DCA, BWI, IAD]              2
# 30721                    3                 [PVD, BOS, MHT]              3
# 32457                    3                 [SFO, OAK, SJC]              3
# 32467                    2                      [MIA, FLL]              2
# 30466                    2                      [PHX, AZA]              1
# 33667                    2                      [ORF, PHF]              2
# 30194                    2                      [DFW, DAL]              2
# 30977                    2                      [ORD, MDW]              1
#
#
#                                                                unique
# OriginCityMarketID
# 31703               [Newark, NJ, New York, NY, Newburgh/Poughkeeps...
# 32575               [Los Angeles, CA, Long Beach, CA, Burbank, CA,...
# 30852                                 [Washington, DC, Baltimore, MD]
# 30721                    [Providence, RI, Boston, MA, Manchester, NH]
# 32457                  [San Francisco, CA, Oakland, CA, San Jose, CA]
# 32467                                [Miami, FL, Fort Lauderdale, FL]
# 30466                                                   [Phoenix, AZ]
# 33667                    [Norfolk, VA, Newport News/Williamsburg, VA]
# 30194                             [Dallas/Fort Worth, TX, Dallas, TX]
# 30977                                                   [Chicago, IL]

# %% [markdown]
# ## Plotting
#
# There are several ways in which we could go about plotting this dataset in order to get acquainted with it.

# %% [markdown]
# For example, do the delays have a relationship with the number of departures a plane does?

# %% [markdown]
# #### Exercise
#
# Do a scatter plot of delays_by_plane with matplotlib, plotting mean delay versus number of departures. Check the documentation

# %%
plt.scatter(delays['count'], delays['mean'])

# %% [markdown]
# Pretty impossible to see anything in there. Maybe a different kind of plottting is required:

# %%
sns.jointplot(delays['count'], delays['mean'], kind='kde')

# %% [markdown]
# #### Exercise:
#
# Plot the distribution of delays as a histogram, both with a linear and a logarithmic scale

# %%
sns.distplot(df3['DepDelay'].dropna(), kde=False, bins=range(-50, 2000, 10))

# %%
sns.distplot(df3['DepDelay'].dropna(), kde=False, bins=range(-50, 2000, 10))
plt.yscale('log')

# %% [markdown]
# #### Exercise:
#
# How do the delays stack over the course of the day? We are going to look at it by plotting the distribution of delays for each hour of the day. The very best way to compare distributions side by side is a boxplot, so we'll use that.

# %%
help(plt.boxplot)
# Out:
# Help on function boxplot in module matplotlib.pyplot:
#
# boxplot(x, notch=None, sym=None, vert=None, whis=None, positions=None, widths=None, patch_artist=None, bootstrap=None, usermedians=None, conf_intervals=None, meanline=None, showmeans=None, showcaps=None, showbox=None, showfliers=None, boxprops=None, labels=None, flierprops=None, medianprops=None, meanprops=None, capprops=None, whiskerprops=None, manage_ticks=True, autorange=False, zorder=None, *, data=None)
#     Make a box and whisker plot.
#
#     Make a box and whisker plot for each column of ``x`` or each
#     vector in sequence ``x``.  The box extends from the lower to
#     upper quartile values of the data, with a line at the median.
#     The whiskers extend from the box to show the range of the
#     data.  Flier points are those past the end of the whiskers.
#
#     Parameters
#     ----------
#     x : Array or a sequence of vectors.
#         The input data.
#
#     notch : bool, optional (False)
#         If `True`, will produce a notched box plot. Otherwise, a
#         rectangular boxplot is produced. The notches represent the
#         confidence interval (CI) around the median. See the entry
#         for the ``bootstrap`` parameter for information regarding
#         how the locations of the notches are computed.
#
#         .. note::
#
#             In cases where the values of the CI are less than the
#             lower quartile or greater than the upper quartile, the
#             notches will extend beyond the box, giving it a
#             distinctive "flipped" appearance. This is expected
#             behavior and consistent with other statistical
#             visualization packages.
#
#     sym : str, optional
#         The default symbol for flier points. Enter an empty string
#         ('') if you don't want to show fliers. If `None`, then the
#         fliers default to 'b+'  If you want more control use the
#         flierprops kwarg.
#
#     vert : bool, optional (True)
#         If `True` (default), makes the boxes vertical. If `False`,
#         everything is drawn horizontally.
#
#     whis : float, sequence, or string (default = 1.5)
#         As a float, determines the reach of the whiskers to the beyond the
#         first and third quartiles. In other words, where IQR is the
#         interquartile range (`Q3-Q1`), the upper whisker will extend to
#         last datum less than `Q3 + whis*IQR`). Similarly, the lower whisker
#         will extend to the first datum greater than `Q1 - whis*IQR`.
#         Beyond the whiskers, data
#         are considered outliers and are plotted as individual
#         points. Set this to an unreasonably high value to force the
#         whiskers to show the min and max values. Alternatively, set
#         this to an ascending sequence of percentile (e.g., [5, 95])
#         to set the whiskers at specific percentiles of the data.
#         Finally, ``whis`` can be the string ``'range'`` to force the
#         whiskers to the min and max of the data.
#
#     bootstrap : int, optional
#         Specifies whether to bootstrap the confidence intervals
#         around the median for notched boxplots. If ``bootstrap`` is
#         None, no bootstrapping is performed, and notches are
#         calculated using a Gaussian-based asymptotic approximation
#         (see McGill, R., Tukey, J.W., and Larsen, W.A., 1978, and
#         Kendall and Stuart, 1967). Otherwise, bootstrap specifies
#         the number of times to bootstrap the median to determine its
#         95% confidence intervals. Values between 1000 and 10000 are
#         recommended.
#
#     usermedians : array-like, optional
#         An array or sequence whose first dimension (or length) is
#         compatible with ``x``. This overrides the medians computed
#         by matplotlib for each element of ``usermedians`` that is not
#         `None`. When an element of ``usermedians`` is None, the median
#         will be computed by matplotlib as normal.
#
#     conf_intervals : array-like, optional
#         Array or sequence whose first dimension (or length) is
#         compatible with ``x`` and whose second dimension is 2. When
#         the an element of ``conf_intervals`` is not None, the
#         notch locations computed by matplotlib are overridden
#         (provided ``notch`` is `True`). When an element of
#         ``conf_intervals`` is `None`, the notches are computed by the
#         method specified by the other kwargs (e.g., ``bootstrap``).
#
#     positions : array-like, optional
#         Sets the positions of the boxes. The ticks and limits are
#         automatically set to match the positions. Defaults to
#         `range(1, N+1)` where N is the number of boxes to be drawn.
#
#     widths : scalar or array-like
#         Sets the width of each box either with a scalar or a
#         sequence. The default is 0.5, or ``0.15*(distance between
#         extreme positions)``, if that is smaller.
#
#     patch_artist : bool, optional (False)
#         If `False` produces boxes with the Line2D artist. Otherwise,
#         boxes and drawn with Patch artists.
#
#     labels : sequence, optional
#         Labels for each dataset. Length must be compatible with
#         dimensions of ``x``.
#
#     manage_ticks : bool, optional (True)
#         If True, the tick locations and labels will be adjusted to match
#         the boxplot positions.
#
#     autorange : bool, optional (False)
#         When `True` and the data are distributed such that the 25th and
#         75th percentiles are equal, ``whis`` is set to ``'range'`` such
#         that the whisker ends are at the minimum and maximum of the data.
#
#     meanline : bool, optional (False)
#         If `True` (and ``showmeans`` is `True`), will try to render
#         the mean as a line spanning the full width of the box
#         according to ``meanprops`` (see below). Not recommended if
#         ``shownotches`` is also True. Otherwise, means will be shown
#         as points.
#
#     zorder : scalar, optional (None)
#         Sets the zorder of the boxplot.
#
#     Other Parameters
#     ----------------
#     showcaps : bool, optional (True)
#         Show the caps on the ends of whiskers.
#     showbox : bool, optional (True)
#         Show the central box.
#     showfliers : bool, optional (True)
#         Show the outliers beyond the caps.
#     showmeans : bool, optional (False)
#         Show the arithmetic means.
#     capprops : dict, optional (None)
#         Specifies the style of the caps.
#     boxprops : dict, optional (None)
#         Specifies the style of the box.
#     whiskerprops : dict, optional (None)
#         Specifies the style of the whiskers.
#     flierprops : dict, optional (None)
#         Specifies the style of the fliers.
#     medianprops : dict, optional (None)
#         Specifies the style of the median.
#     meanprops : dict, optional (None)
#         Specifies the style of the mean.
#
#     Returns
#     -------
#     result : dict
#       A dictionary mapping each component of the boxplot to a list
#       of the :class:`matplotlib.lines.Line2D` instances
#       created. That dictionary has the following keys (assuming
#       vertical boxplots):
#
#       - ``boxes``: the main body of the boxplot showing the
#         quartiles and the median's confidence intervals if
#         enabled.
#
#       - ``medians``: horizontal lines at the median of each box.
#
#       - ``whiskers``: the vertical lines extending to the most
#         extreme, non-outlier data points.
#
#       - ``caps``: the horizontal lines at the ends of the
#         whiskers.
#
#       - ``fliers``: points representing data that extend beyond
#         the whiskers (fliers).
#
#       - ``means``: points or lines representing the means.
#
#     Notes
#     -----
#
#
#     .. note::
#         In addition to the above described arguments, this function can take a
#         **data** keyword argument. If such a **data** argument is given, the
#         following arguments are replaced by **data[<arg>]**:
#
#         * All positional and all keyword arguments.
#
#         Objects passed as **data** must support item access (``data[<arg>]``) and
#         membership test (``<arg> in data``).

# %% [markdown]
# We need to provide `plt.boxplot()` with a sequence that contains 24 elements. Each of those will be a sequence containing every individual delay for one hour of the day. We'll need, therefore, to extract hours of the day for each departure and group based on that.

# %%
ax = sns.boxplot(data=df3, x='Hour', y='DepDelay')
ax.set_ylim(-50, 150)
plt.gcf().set_size_inches(12, 6)

# %% [markdown]
# #### Exercise
#
# We are also interested in examining how the home base influences delays. Do a boxplot of the delay distribution for the 10 airports with the most flights, and the 10 airports with the least flights.

# %% [markdown]
# #### Take home project
#
# If we wanted to do some machine learning, we would need to create as many informative features as we thought could be useful. This is called Feature Engineering.
#
# Discrete data would most often be transformed by [one-hot encoding](https://hackernoon.com/what-is-one-hot-encoding-why-and-when-do-you-have-to-use-it-e3c6186d008f), which is [very easy to do in pandas](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.get_dummies.html).
#
# ![One Hot Encoding](https://hackernoon.com/photos/4HK5qyMbWfetPhAavzyTZrEb90N2-3o23tie)
#
# With high cardinality discrete data such as airports or, especially, tail numbers, we would be left with many variables, most of which would not be very informative. There are [several options](https://www.datacamp.com/community/tutorials/encoding-methodologies) to deal with this. The most sophisticated is probably vector encoding, but we can do with a very simple approach: [target encoding](https://maxhalford.github.io/blog/target-encoding-done-the-right-way/).
#
# This means that we substitute each value of the discrete variable by the average or median value of the target variable for that value of the independent discrete variable. However! if we want to use this in machine learning for predictions, we would need to use only the previous values.
#
# Target encode the variable 'Origin' and the 'Tail_Number' variable, using for each cell only the values that were available the previous day. In other words: create a `median_delay_origin` variable that contains, for each record, the median delay at that airport _up to the previous day_. Create another one, `median_delay_plane`, with Tail_Number.

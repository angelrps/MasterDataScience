# %%
#entrar en https://datos.madrid.es/ catalogo de datos

# %% [markdown]
# # Loading CSV

# %%
import pandas as pd

# %%
# !ls
# Out:
#  01_					      ACCIDENTES_POR_TIPO
# '01_ ACCIDENTES_POR_TIPO_EN  DISTRITOS.xls'   AccidentesBicicletas_2019.csv
#  01_intro_to_DS_toolkit_MINE.ipynb	      accidentes.csv
#  01_intro_to_DS_toolkit_halfempty.ipynb       houses.csv
#  02-loading_and_saving_data_empty.ipynb       newdb.db
#  03-merge_concatenate_transform_empty.ipynb   results.csv
#  04-group_by_empty.ipynb		      results.xlsx
#  05-visualization_introduction_empty.ipynb    train.csv

# %%
# !head ./AccidentesBicicletas_2019.csv
# Out:
# Nº  EXPEDIENTE;FECHA;HORA;CALLE;NÚMERO;DISTRITO;TIPO ACCIDENTE;ESTADO METEREOLÓGICO;TIPO VEHÍCULO;TIPO PERSONA;RANGO DE EDAD;SEXO;LESIVIDAD*
# 2019S000659;01/01/2019;14:00;CALL. CASTELLO / CALL. DON RAMON DE LA CRUZ;-;SALAMANCA;Alcance;Despejado;Bicicleta;Conductor;DE 25 A 29 AÑOS;Hombre;01
# 2019S000036;02/01/2019;20:45;AVDA. GRAN VIA DE HORTALEZA / GTA. LUIS ROSALES;-;HORTALEZA;Colisión fronto-lateral;Despejado;Bicicleta;Conductor;DE 70 A 74 AÑOS;Hombre;03
# 2019S000133;03/01/2019;14:30;CALL. FELIPE ALVAREZ;10;VILLA DE VALLECAS;Alcance;Se desconoce;Bicicleta;Conductor;DE 15 A 17 AÑOS;Hombre;07
# 2019S000132;03/01/2019;12:45;AVDA. SANTA EUGENIA / CALL. REAL DE ARGANDA;-;VILLA DE VALLECAS;Alcance;Despejado;Bicicleta;Conductor;DE 18 A 20 AÑOS;Hombre;07
# 2019S000132;03/01/2019;12:45;AVDA. SANTA EUGENIA / CALL. REAL DE ARGANDA;-;VILLA DE VALLECAS;Alcance;Despejado;Bicicleta;Conductor;DE 21 A 24 AÑOS;Hombre;14
# ...

# %%
pd.read_csv('./AccidentesBicicletas_2019.csv', sep=';') #hay que especificar el separador
# Out:
#     Nº  EXPEDIENTE       FECHA   HORA  \
# 0      2019S000659  01/01/2019  14:00
# 1      2019S000036  02/01/2019  20:45
# 2      2019S000133  03/01/2019  14:30
# 3      2019S000132  03/01/2019  12:45
# 4      2019S000132  03/01/2019  12:45
# ..             ...         ...    ...
# 774    2019S034457  29/10/2019  20:10
# 775    2019S034336  29/10/2019  11:00
# 776    2019S034331  30/10/2019  10:00
# 777    2019S034555  31/10/2019  21:05
# 778    2019S034565  31/10/2019  15:50
#
#                                                CALLE NÚMERO  \
# 0        CALL. CASTELLO / CALL. DON RAMON DE LA CRUZ      -
# 1    AVDA. GRAN VIA DE HORTALEZA / GTA. LUIS ROSALES      -
# 2                               CALL. FELIPE ALVAREZ     10
# 3        AVDA. SANTA EUGENIA / CALL. REAL DE ARGANDA      -
# 4        AVDA. SANTA EUGENIA / CALL. REAL DE ARGANDA      -
# ..                                               ...    ...
# 774                               CALL. ARTURO SORIA   334A
# ...

# %%
#al profe le da un error de "encoding" que lo soluciona poniendo enconding='latin1', simplemente porque él ya se lo sabe.
#y sabe que ese es el enconding que hay que usar la mmayoría de las veces.

# %%
df = pd.read_csv('./AccidentesBicicletas_2019.csv', encoding='latin1', sep=';')
df
# Out:
#     NÂº  EXPEDIENTE       FECHA   HORA  \
# 0       2019S000659  01/01/2019  14:00
# 1       2019S000036  02/01/2019  20:45
# 2       2019S000133  03/01/2019  14:30
# 3       2019S000132  03/01/2019  12:45
# 4       2019S000132  03/01/2019  12:45
# ..              ...         ...    ...
# 774     2019S034457  29/10/2019  20:10
# 775     2019S034336  29/10/2019  11:00
# 776     2019S034331  30/10/2019  10:00
# 777     2019S034555  31/10/2019  21:05
# 778     2019S034565  31/10/2019  15:50
#
#                                                CALLE NÃMERO  \
# 0        CALL. CASTELLO / CALL. DON RAMON DE LA CRUZ       -
# 1    AVDA. GRAN VIA DE HORTALEZA / GTA. LUIS ROSALES       -
# 2                               CALL. FELIPE ALVAREZ      10
# 3        AVDA. SANTA EUGENIA / CALL. REAL DE ARGANDA       -
# 4        AVDA. SANTA EUGENIA / CALL. REAL DE ARGANDA       -
# ..                                               ...     ...
# ...

# %%
pd.Series(df.columns).str.lower().str.replace

# %% [markdown]
# # Saving to Excel

# %%
df.to_excel('./results.xlsx')

# %% [markdown]
# # Saving to CSV

# %%
df.to_csv('./results.csv', sep='^') #le cambiamos el separador al que queremos

# %% [markdown]
# # Reading Excel

# %%
#he llegado tarde mirar en el notebook del profe.
#en resumen este excel está super sucio y ha mostrado muchas opciones para skip columnas, index, nan values y tal

# %% [markdown]
# #### Exercise
#
# Consolidate the excel into one DataFrame: you will need to create a 'YEAR' column. Think how you can iterate through all the DataFrames. Think also where you can take the value of 'YEAR' from.

# %%
#ejercicio. Hacer una tabla juntando todos los sheets en uno. añadiendo una columna que sea AÑO. Porque hay una sheet por año.

# %% [markdown]
# # To Sql Database

# %%
import sqlite3

connection = sqlite3.connect('newdb.db') #hay que crear esta conexión a una base de datos

# %%
df.to_sql('mynewtable', con=connection, if_exists='replace')
# Out:
# /home/angelrps/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py:2712: UserWarning: The spaces in these column names will not be changed. In pandas versions < 0.14, spaces were converted to underscores.
#   method=method,

# %% [markdown]
# # To dictionary and to json

# %%
df.head().to_dict() #lo convierto en un dict
# Out:
# {'NÂº  EXPEDIENTE': {0: '2019S000659',
#   1: '2019S000036',
#   2: '2019S000133',
#   3: '2019S000132',
#   4: '2019S000132'},
#  'FECHA': {0: '01/01/2019',
#   1: '02/01/2019',
#   2: '03/01/2019',
#   3: '03/01/2019',
#   4: '03/01/2019'},
#  'HORA': {0: '14:00', 1: '20:45', 2: '14:30', 3: '12:45', 4: '12:45'},
#  'CALLE': {0: 'CALL. CASTELLO / CALL. DON RAMON DE LA CRUZ',
#   1: 'AVDA. GRAN VIA DE HORTALEZA / GTA. LUIS ROSALES',
#   2: 'CALL. FELIPE ALVAREZ',
#   3: 'AVDA. SANTA EUGENIA / CALL. REAL DE ARGANDA',
#   4: 'AVDA. SANTA EUGENIA / CALL. REAL DE ARGANDA'},
#  'NÃ\x9aMERO': {0: '-', 1: '-', 2: '10', 3: '-', 4: '-'},
#  'DISTRITO': {0: 'SALAMANCA',
#   1: 'HORTALEZA',
#   2: 'VILLA DE VALLECAS',
#   3: 'VILLA DE VALLECAS',
#   4: 'VILLA DE VALLECAS'},
#  'TIPO ACCIDENTE': {0: 'Alcance',
#   1: 'ColisiÃ³n fronto-lateral',
#   2: 'Alcance',
#   3: 'Alcance',
#   4: 'Alcance'},
#  'ESTADO METEREOLÃ\x93GICO': {0: 'Despejado',
#   1: 'Despejado',
#   2: 'Se desconoce',
# ...

# %%
df.head().to_json()
# Out:
# '{"N\\u00c2\\u00ba  EXPEDIENTE":{"0":"2019S000659","1":"2019S000036","2":"2019S000133","3":"2019S000132","4":"2019S000132"},"FECHA":{"0":"01\\/01\\/2019","1":"02\\/01\\/2019","2":"03\\/01\\/2019","3":"03\\/01\\/2019","4":"03\\/01\\/2019"},"HORA":{"0":"14:00","1":"20:45","2":"14:30","3":"12:45","4":"12:45"},"CALLE":{"0":"CALL. CASTELLO \\/ CALL. DON RAMON DE LA CRUZ","1":"AVDA. GRAN VIA DE HORTALEZA \\/ GTA. LUIS ROSALES","2":"CALL. FELIPE ALVAREZ","3":"AVDA. SANTA EUGENIA \\/ CALL. REAL DE ARGANDA","4":"AVDA. SANTA EUGENIA \\/ CALL. REAL DE ARGANDA"},"N\\u00c3\\u009aMERO":{"0":"-","1":"-","2":"10","3":"-","4":"-"},"DISTRITO":{"0":"SALAMANCA","1":"HORTALEZA","2":"VILLA DE VALLECAS","3":"VILLA DE VALLECAS","4":"VILLA DE VALLECAS"},"TIPO ACCIDENTE":{"0":"Alcance","1":"Colisi\\u00c3\\u00b3n fronto-lateral","2":"Alcance","3":"Alcance","4":"Alcance"},"ESTADO METEREOL\\u00c3\\u0093GICO":{"0":"Despejado","1":"Despejado","2":"Se desconoce","3":"Despejado","4":"Despejado"},"TIPO VEH\\u00c3\\u0
# ...

# %% [markdown]
# # Reading mysql database

# %%
pd.read_sql_query("SELECT FECHA, HORA FROM mynewtable WHERE SEXO = 'Hombre'LIMIT 10", connection)
#la forma de leer sql es hacer una query en lenguaje SQL
# Out:
#         FECHA   HORA
# 0  01/01/2019  14:00
# 1  02/01/2019  20:45
# 2  03/01/2019  14:30
# 3  03/01/2019  12:45
# 4  03/01/2019  12:45
# 5  03/01/2019  10:30
# 6  04/01/2019  17:10
# 7  04/01/2019  13:35
# 8  07/01/2019  14:00
# 9  08/01/2019  20:55
